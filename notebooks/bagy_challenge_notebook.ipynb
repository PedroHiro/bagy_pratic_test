# %%
# Carregamento das bibliotecas necessarias

import pandas as pd

# %%
# Carregamento do arquivo csv

df = pd.read_csv('../bases/teste_dados_ecommerce.csv', encoding='unicode_escape',sep=';')
df
# Out:
#        InvoiceNo  StoreId StockCode                          Description  \
# 0         536365       11    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1         536365        9     71053                  WHITE METAL LANTERN
# 2         536365       17    84406B       CREAM CUPID HEARTS COAT HANGER
# 3         536365       15    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4         536365       17    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...          ...      ...       ...                                  ...
# 541904    581587        7     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905    581587       14     22899         CHILDREN'S APRON DOLLY GIRL
# 541906    581587        7     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907    581587       17     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908    581587        9     22138        BAKING SET 9 PIECE RETROSPOT
#
#         Quantity     InvoiceDate  UnitPrice  CustomerID         Country
# 0              6  12/01/10 08:26       2.55     17850.0  United Kingdom
# 1              6  12/01/10 08:26       3.39     17850.0  United Kingdom
# 2              8  12/01/10 08:26       2.75     17850.0  United Kingdom
# 3              6  12/01/10 08:26       3.39     17850.0  United Kingdom
# 4              6  12/01/10 08:26       3.39     17850.0  United Kingdom
# ...          ...             ...        ...         ...             ...
# 541904        12  12/09/11 12:50       0.85     12680.0          France
# 541905         6  12/09/11 12:50       2.10     12680.0          France
# 541906         4  12/09/11 12:50       4.15     12680.0          France
# 541907         4  12/09/11 12:50       4.15     12680.0          France
# 541908         3  12/09/11 12:50       4.95     12680.0          France
#
# [541909 rows x 9 columns]

# %%
df.keys()
# Out:
# Index(['InvoiceNo', 'StoreId', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')
